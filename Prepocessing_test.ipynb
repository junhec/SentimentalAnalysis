# %%
import pandas as pd
import numpy as np

train=pd.read_csv('train.csv')
test=pd.read_csv('test.csv')
type(train)
# Out:
# pandas.core.frame.DataFrame

# %%
new=pd.merge(train, test, on='Id')
new
# Out:
#        HelpfulnessDenominator  HelpfulnessNumerator      Id   ProductId  \
# 0                           2                     0  413937  B0029ZAOW8
# 1                           0                     0   16525  B001LGGH40
# 2                           1                     1  221883  B001LNTY70
# 3                           0                     0   82207  B005ZBZLT4
# 4                           0                     0    8354  B003VXFK44
# 5                           3                     3  483228  B002AYIJDO
# 6                           0                     0  350796  B002QWP8H0
# 7                           0                     0  121313  B000CQBZOW
# 8                           7                     7  494256  B000YVGMZW
# 9                           0                     0  260366  B004EAGP74
# 10                          0                     0   48796  B003LECIDE
# 11                          0                     0  255690  B000H7LVKY
# ...

# %%
with open("./testText.txt", "w") as text_file:
    for index, row in new.iterrows():
        text_file.write(row['Text'])
        text_file.write('\n')
